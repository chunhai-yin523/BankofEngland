# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_excel('Data1.xlsx', index_col=0, header=[0,1]) # 325 X 40
df2 = pd.read_excel('Data2.xlsx', index_col=0, header=[0,1]) # 325 X 45

# merge data frames
df = df1.merge(df2, left_index=True, right_index=True) # 325 X 85

# %%
check_for_nan = df.isnull().values.any()
print (check_for_nan)
df = df.fillna(0)
# Out:
# True

# %%
# get item list
item_list = []
for i in range(len(df.columns)):
    if df.columns[i][0] not in item_list:
        item_list.append(df.columns[i][0])
    
item_list = tuple(item_list)
#item_list

# %%
# delete rows with more than 3 zeros in the item
def clean_percentage(df, column_name):
    col = column_name
    for index in df.index:
        unique = df[[col]].loc[index].nunique()
        percentage = float(unique) / len(df[[col]].loc[index])
        if percentage < 0.8:
            print ('Deleted: ', index)
            df.drop(index, axis=0, inplace=True)
    return df

# %%
df = clean_percentage(df, 'GWP (£m)')
df
# Out:
# Deleted:  Firm 1
# Deleted:  Firm 8
# Deleted:  Firm 11
# Deleted:  Firm 12
# Deleted:  Firm 16
# Deleted:  Firm 18
# Deleted:  Firm 19
# Deleted:  Firm 20
# Deleted:  Firm 21
# Deleted:  Firm 24
# Deleted:  Firm 27
# Deleted:  Firm 29
# Deleted:  Firm 31
# Deleted:  Firm 37
# Deleted:  Firm 43
# Deleted:  Firm 50
# Deleted:  Firm 56
# Deleted:  Firm 58
# Deleted:  Firm 60
# Deleted:  Firm 65
# Deleted:  Firm 67
# Deleted:  Firm 68
# Deleted:  Firm 71
# Deleted:  Firm 79
# Deleted:  Firm 83
# Deleted:  Firm 84
# Deleted:  Firm 85
# Deleted:  Firm 90
# Deleted:  Firm 94
# Deleted:  Firm 95
# Deleted:  Firm 96
# Deleted:  Firm 98
# Deleted:  Firm 102
# Deleted:  Firm 103
# Deleted:  Firm 108
# Deleted:  Firm 109
# Deleted:  Firm 110
# Deleted:  Firm 112
# Deleted:  Firm 116
# Deleted:  Firm 117
# Deleted:  Firm 119
# Deleted:  Firm 122
# Deleted:  Firm 125
# Deleted:  Firm 127
# Deleted:  Firm 128
# Deleted:  Firm 129
# Deleted:  Firm 131
# Deleted:  Firm 135
# Deleted:  Firm 137
# Deleted:  Firm 140
# Deleted:  Firm 141
# Deleted:  Firm 145
# Deleted:  Firm 147
# Deleted:  Firm 153
# Deleted:  Firm 155
# Deleted:  Firm 160
# Deleted:  Firm 162
# Deleted:  Firm 168
# Deleted:  Firm 172
# Deleted:  Firm 176
# Deleted:  Firm 190
# Deleted:  Firm 197
# Deleted:  Firm 198
# Deleted:  Firm 202
# Deleted:  Firm 206
# Deleted:  Firm 207
# Deleted:  Firm 215
# Deleted:  Firm 216
# Deleted:  Firm 217
# Deleted:  Firm 224
# Deleted:  Firm 232
# Deleted:  Firm 233
# Deleted:  Firm 238
# Deleted:  Firm 239
# Deleted:  Firm 249
# Firm 4    0.092971  0.054781 -0.546237             0.848032  1.474778
# Firm 5    0.109074  0.121044  0.109187             0.508711  1.259454
# Firm 6    0.232953  0.198427  0.155372             1.262200  0.840078
# ...            ...       ...       ...                  ...       ...
# Firm 318  0.626588  0.925025  0.756106             0.214787 -0.075744
# Firm 321  0.245704  0.236224  0.278674             0.978004  1.002691
# Firm 322  0.398770  0.420327  0.373813             0.885956  0.960993
# Firm 324  0.357627  0.330893  0.302577             1.063136  1.006945
# Firm 325  0.037627  0.043566  0.045283             0.164648  0.183376
#
#
#             2018YE    2019YE     2020YE
# Firm 2    0.939197  0.000000   0.000000
# Firm 3    0.000000  0.000000   0.000000
# Firm 4    1.727968  1.208823 -10.736084
# Firm 5    1.304168  0.983277   0.997184
# Firm 6    0.922944  0.769213   0.752116
# ...            ...       ...        ...
# Firm 318  1.508934  1.482219   0.988902
# Firm 321  0.972540  0.958443   0.816870
# Firm 322  0.913687  0.943246   0.995833
# Firm 324  0.982816  0.994712   0.780065
# Firm 325  0.427933  0.274733   0.180449
#
# [230 rows x 85 columns]

# %%
# select the largest n rows based on mean values
def get_large(df, column_name, n):
    col = column_name
    df_mean = df[[col]].mean(axis=1).to_frame(name = 'mean') # create mean df
    df_large = df_mean.nlargest(n, 'mean') # select largest 
    df_large_selected = df.loc[df_large.index] # select from df
    return df_large_selected

# %%
df = get_large(df, 'GWP (£m)', 10)
#df

# %%
def plot_xfirm(df, ylog, ymin, ymax):
    fig, ax = plt.subplots(figsize=(6, 4))
    ax = df.T.boxplot()
    ax.set_ylabel(df.columns[0][0])
    
    if ymin == None and ymax == None:
        pass
    else:
        ax.set_ylim([ymin, ymax])
    
    if ylog == True:
        ax.set_yscale('log')
        
    plt.xticks(rotation=90)
    plt.title(df.columns[0][0])
    plt.tight_layout()
    plt.savefig('fig_' + str(df.columns[0][0]) + '.png', dpi=900)
    plt.show()

# %%
plot_xfirm(df[['GWP (£m)']], ylog=True, ymin=1e3, ymax=1e5)

# %%
df_gwp = df[('GWP (£m)')]
df_nwp = df[('NWP (£m) ')]

# %%
a = df[('NWP (£m) ')] / df[('GWP (£m)')]
a
header = [np.array(['NWP/GWP', 'NWP/GWP', 'NWP/GWP','NWP/GWP','NWP/GWP']), np.array(['2016YE','2017YE','2018YE','2019YE','2020YE'])] 
new_df = pd.DataFrame(a, index=a.index, columns = header)
new_df
# nwp_gwp = df[('NWP (£m) ')] / df[('GWP (£m)')]
# df_nwp_gwp = 
#df_nwp_gwp = df_nwp / df_gwp
#df_nwp_gwp
# Out:
#          NWP/GWP NWP/GWP NWP/GWP NWP/GWP NWP/GWP
# Firm 210     NaN     NaN     NaN     NaN     NaN
# Firm 4       NaN     NaN     NaN     NaN     NaN
# Firm 26      NaN     NaN     NaN     NaN     NaN
# Firm 247     NaN     NaN     NaN     NaN     NaN
# Firm 34      NaN     NaN     NaN     NaN     NaN
# Firm 105     NaN     NaN     NaN     NaN     NaN
# Firm 311     NaN     NaN     NaN     NaN     NaN
# Firm 7       NaN     NaN     NaN     NaN     NaN
# Firm 73      NaN     NaN     NaN     NaN     NaN
# Firm 151     NaN     NaN     NaN     NaN     NaN

# %%
def plot_nwp_gwp():
    df_plot = df_nwp_gwp
    name = 'NWP/GWP'

    fig, ax = plt.subplots(figsize=(6, 4))
    ax = df_plot.T.boxplot()
    ax.set_ylabel(name)
    ax.set_ylim([-0.3, 1.3])
    #ax.set_yscale('log')
    plt.xticks(rotation=90)
    plt.title(name)
    plt.tight_layout()
    plt.savefig('fig_nwp_gwp.png', dpi=900)
    plt.show()

# %%
plot_nwp_gwp()

# %%
plot_xfirm(df[['SCR coverage ratio']], ylog=True, ymin=1e0, ymax=1.1e1)
#df

# %%
def plot_combined(df1, df2, xlog, ylog, xmin, xmax, ymin, ymax):
    fig, ax = plt.subplots(figsize=(6, 4))
    for index in df1.index:
        ax.scatter(df1.loc[index], df2.loc[index], label=index)
    
    ax.fill_between((0, df1.max().max()), 0, 1, color = 'grey', alpha=0.3)
    
    if xmin == None and xmax == None:
        pass
    else:
        ax.set_ylim([xmin, xmax])
    
    if ymin == None and ymax == None:
        pass
    else:
        ax.set_ylim([ymin, ymax])
    
    if xlog == True:
        ax.set_xscale('log')
    if ylog == True:
        ax.set_yscale('log')
    
    ax.set_xlabel(df1.columns[0][0])
    ax.set_ylabel(df2.columns[0][0])

    plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc='lower left', mode="expand", borderaxespad=0, ncol=3)
    plt.tight_layout()
    plt.savefig('fig_comb_'+ str(df1.columns[0][0]) + str(df2.columns[0][0]) + '.png', dpi=900)
    plt.show()

# %%
plot_combined(df[['NWP (£m) ']], df[['Net combined ratio']], xlog=True, ylog=False, xmin=None, xmax=None, ymin=-0.1, ymax=1.1)

# %%
def plot_xyear(df, ylog, ymin, ymax):
    fig, ax = plt.subplots(figsize=(6, 4))
    
    year = ['2016', '2017', '2018', '2019', '2020']
    ax.set_xlabel('Year')
    ax.set_ylabel(df.columns[0][0])
    
    for index in df.index:
        ax.plot(year, df.loc[index], marker = 'o', label=index)

    if ymin == None and ymax == None:
        pass
    else:
        ax.set_ylim([ymin, ymax])
    
    if ylog == True:
        ax.set_yscale('log')    
        
    plt.xticks()
    plt.title(df.columns[0][0])
    plt.legend(bbox_to_anchor=(1.04,0.5), loc="center left", borderaxespad=0)
    plt.tight_layout()
    plt.savefig('fig_' + str(df.columns[0][0]) + '.png', dpi=900)
    plt.show()

# %%
plot_xyear(df[['Gross claims incurred (£m)']], ylog=False, ymin=None, ymax=None)

# %%
plot_xfirm(df[['Net combined ratio']], ylog=False, ymin=None, ymax=None)
